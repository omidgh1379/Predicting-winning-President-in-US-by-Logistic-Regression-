# %% [markdown]
# **import the dataset and library**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/president_county_candidate.csv')
data
# Out:
#           state             county      candidate party  total_votes    won
# 0      Delaware        Kent County      Joe Biden   DEM        44552   True
# 1      Delaware        Kent County   Donald Trump   REP        41009  False
# 2      Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3      Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4      Delaware  New Castle County      Joe Biden   DEM       195034   True
# ...         ...                ...            ...   ...          ...    ...
# 31278   Arizona    Maricopa County   Donald Trump   REP       995665  False
# 31279   Arizona    Maricopa County   Jo Jorgensen   LIB        31705  False
# 31280   Arizona      Mohave County   Donald Trump   REP        78535   True
# 31281   Arizona      Mohave County      Joe Biden   DEM        24831  False
# 31282   Arizona      Mohave County   Jo Jorgensen   LIB         1302  False
#
# [31283 rows x 6 columns]

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
#  **handle cat**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31283 entries, 0 to 31282
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        31283 non-null  object
#  1   county       31283 non-null  object
#  2   candidate    31283 non-null  object
#  3   party        31283 non-null  object
#  4   total_votes  31283 non-null  int64
#  5   won          31283 non-null  bool
# dtypes: bool(1), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
data1 = data.replace({'won' : True} , 1).replace({'won' : False} , 0)
data1
# Out:
#           state             county      candidate party  total_votes  won
# 0      Delaware        Kent County      Joe Biden   DEM        44552  1.0
# 1      Delaware        Kent County   Donald Trump   REP        41009  0.0
# 2      Delaware        Kent County   Jo Jorgensen   LIB         1044  0.0
# 3      Delaware        Kent County  Howie Hawkins   GRN          420  0.0
# 4      Delaware  New Castle County      Joe Biden   DEM       195034  1.0
# ...         ...                ...            ...   ...          ...  ...
# 31278   Arizona    Maricopa County   Donald Trump   REP       995665  0.0
# 31279   Arizona    Maricopa County   Jo Jorgensen   LIB        31705  0.0
# 31280   Arizona      Mohave County   Donald Trump   REP        78535  1.0
# 31281   Arizona      Mohave County      Joe Biden   DEM        24831  0.0
# 31282   Arizona      Mohave County   Jo Jorgensen   LIB         1302  0.0
#
# [31283 rows x 6 columns]

# %%
print(np.unique(data1.party)) 
print()        #number of unique value of party
print(data1.party.value_counts())
# Out:
# ['ALI' 'APV' 'ASP' 'BAR' 'BFP' 'BMP' 'CST' 'DEM' 'GOP' 'GRN' 'IAP' 'IND'
#  'LIB' 'LLC' 'LLP' 'NON' 'OTH' 'PRG' 'PRO' 'PSL' 'REP' 'SEP' 'SWP' 'UNA'
#  'UTY' 'WRI']
#
# LIB    4633
# DEM    4633
# REP    4633
# IND    3288
# GRN    3034
# WRI    2898
# ALI    1562
# CST    1350
# PSL    1028
# ASP     745
# SWP     595
# PRO     467
# IAP     310
# APV     310
# BAR     270
# BMP     246
# BFP     246
# GOP     246
# UNA     221
# UTY     149
# PRG     100
# OTH      99
# LLP      75
# SEP      64
# LLC      64
# NON      17
# Name: party, dtype: int64

# %%
data1.candidate.value_counts()
# Out:
# Jo Jorgensen                 4633
# Donald Trump                 4633
# Joe Biden                    4633
# Howie Hawkins                2994
#  Write-ins                   2898
# Rocky De La Fuente           1562
# Don Blankenship              1317
# Brock Pierce                 1124
# Kanye West                   1082
# Gloria La Riva               1028
# Brian Carroll                 745
# Alyson Kennedy                595
# Phil Collins                  467
# Kyle Kopitke                  310
# Blake Huber                   310
# Jerome Segal                  270
# Keith McCormic                246
# Gary Swing                    246
# Richard Duncan                246
# Christopher LaFontaine        246
# Zachary Scalf                 246
# Brooke Paige                  246
# Bill Hammons                  149
# Jade Simmons                  141
# Dario Hunter                  100
# Ricki Sue King                 99
# Joe McHugh                     93
# ...

# %%
data2 = data1.drop(['state' , 'county' ] , axis = 1)
data2
# Out:
#            candidate party  total_votes  won
# 0          Joe Biden   DEM        44552  1.0
# 1       Donald Trump   REP        41009  0.0
# 2       Jo Jorgensen   LIB         1044  0.0
# 3      Howie Hawkins   GRN          420  0.0
# 4          Joe Biden   DEM       195034  1.0
# ...              ...   ...          ...  ...
# 31278   Donald Trump   REP       995665  0.0
# 31279   Jo Jorgensen   LIB        31705  0.0
# 31280   Donald Trump   REP        78535  1.0
# 31281      Joe Biden   DEM        24831  0.0
# 31282   Jo Jorgensen   LIB         1302  0.0
#
# [31283 rows x 4 columns]

# %%
data3 = pd.get_dummies(data2)
data3
# Out:
#        total_votes  won  ...  party_UTY  party_WRI
# 0            44552  1.0  ...          0          0
# 1            41009  0.0  ...          0          0
# 2             1044  0.0  ...          0          0
# 3              420  0.0  ...          0          0
# 4           195034  1.0  ...          0          0
# ...            ...  ...  ...        ...        ...
# 31278       995665  0.0  ...          0          0
# 31279        31705  0.0  ...          0          0
# 31280        78535  1.0  ...          0          0
# 31281        24831  0.0  ...          0          0
# 31282         1302  0.0  ...          0          0
#
# [31283 rows x 66 columns]

# %% [markdown]
# **duplicated**

# %%
data3.duplicated().sum()

data4 = data3.drop_duplicates().reset_index().drop('index' , axis = 1)
data4
# Out:
#        total_votes  won  ...  party_UTY  party_WRI
# 0            44552  1.0  ...          0          0
# 1            41009  0.0  ...          0          0
# 2             1044  0.0  ...          0          0
# 3              420  0.0  ...          0          0
# 4           195034  1.0  ...          0          0
# ...            ...  ...  ...        ...        ...
# 11524       995665  0.0  ...          0          0
# 11525        31705  0.0  ...          0          0
# 11526        78535  1.0  ...          0          0
# 11527        24831  0.0  ...          0          0
# 11528         1302  0.0  ...          0          0
#
# [11529 rows x 66 columns]

# %% [markdown]
# **missing value**

# %%
data4.isna().sum()
# Out:
# total_votes                            0
# won                                    0
# candidate_ None of these candidates    0
# candidate_ Write-ins                   0
# candidate_Alyson Kennedy               0
#                                       ..
# party_SEP                              0
# party_SWP                              0
# party_UNA                              0
# party_UTY                              0
# party_WRI                              0
# Length: 66, dtype: int64

# %% [markdown]
# **handle imbalance data imbalanced data**

# %%
data4.won.value_counts()
# Out:
# 0.0    7361
# 1.0    4168
# Name: won, dtype: int64

# %%
X = data4.drop(columns = 'won' , axis = 1)

y = data4.iloc[: , 1]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()

X_smote , y_smote = smote.fit_resample(X , y)

# %%
y_smote.value_counts()
# Out:
# 0.0    7361
# 1.0    7361
# Name: won, dtype: int64

# %% [markdown]
# **feature scaling**

# %%
from sklearn.preprocessing import MinMaxScaler

min_max = MinMaxScaler()

X_mm = min_max.fit_transform(X_smote)

# %%
X_mm = pd.DataFrame(X_mm , columns = X_smote.columns)
X_mm
# Out:
#        total_votes  candidate_ None of these candidates  ...  party_UTY  party_WRI
# 0         0.014841                                  0.0  ...        0.0        0.0
# 1         0.013661                                  0.0  ...        0.0        0.0
# 2         0.000348                                  0.0  ...        0.0        0.0
# 3         0.000140                                  0.0  ...        0.0        0.0
# 4         0.064971                                  0.0  ...        0.0        0.0
# ...            ...                                  ...  ...        ...        ...
# 14717     0.001216                                  0.0  ...        0.0        0.0
# 14718     0.000613                                  0.0  ...        0.0        0.0
# 14719     0.032190                                  0.0  ...        0.0        0.0
# 14720     0.003347                                  0.0  ...        0.0        0.0
# ...

# %% [markdown]
# # splitting the data in train test

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test  =  train_test_split(X_mm , y_smote ,test_size = 0.3 , random_state = 42)

# %% [markdown]
# **training the model using Logistic regression**

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import GridSearchCV

model = LogisticRegressionCV()

# %% [markdown]
# **finding the best hyper parameters**

# %%
model.get_params()
# Out:
# {'Cs': 10,
#  'class_weight': None,
#  'cv': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1.0,
#  'l1_ratios': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'refit': True,
#  'scoring': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0}

# %%
weight = [ 5 , 8,9,10, 12, 20 ]

grid = GridSearchCV(model , param_grid = {'Cs' : weight , 'penalty' : ['l2']} , cv  = 3 ,return_train_score=True , scoring = 'f1')
grid.fit(X_train , y_train)
grid.best_params_
# Out:
# {'Cs': 10, 'penalty': 'l2'}

# %%
model = LogisticRegressionCV(Cs = 10)



model.fit(X_train , y_train)
# Out:
# LogisticRegressionCV()

# %%
y_pred = model.predict(X_test)

y_pred
# Out:
# array([0., 1., 0., ..., 0., 1., 0.])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred , y_test)
# Out:
# 0.8159384197419063

# %%
from sklearn.metrics import f1_score

f1_score(y_pred , y_test)
# Out:
# 0.8127159640635797

# %% [markdown]
# **checking that we have overfitting or not**

# %%
y_pred_train = model.predict(X_train)

accuracy_score(y_pred_train , y_train)
# Out:
# 0.8200873362445414
